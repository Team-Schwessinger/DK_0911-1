# %%
import pandas as pd
import os
import shutil
from Bio import SeqIO
from Bio import AlignIO
import distance
import editdistance
import math
import subprocess
import numpy as np

# %%
BASE_OUT_PATH = '/home/gamran/genome_analysis/Warrior/Richard/output/post_analysis/'
ALLELE_PATH = '/home/gamran/genome_analysis/Warrior/Richard/output/defining_alleles_2/allele_analysis/alleles_proteinortho_graph516/'
GENOME_PATH = '/home/gamran/genome_analysis/Warrior/Richard/output/genome_v03/'

PAML_PATH = os.path.join(BASE_OUT_PATH, 'paml')
if not os.path.exists(PAML_PATH):
    os.mkdir(PAML_PATH)

# %%
# Create DataFrame with all alleles
overlapDf = pd.read_csv(os.path.join(ALLELE_PATH, 'DK_0911_v03_p_ctg.h_contig_overlap.alleles'), header=None, names=['alleleOne', 'alleleTwo'], sep='\t')
noOverlapDf = pd.read_csv(os.path.join(ALLELE_PATH, 'DK_0911_v03_p_ctg.no_specific_h_contig_overlap.alleles'), header=None, names=['alleleOne', 'alleleTwo'], sep='\t')
diffContigDf = pd.read_csv(os.path.join(ALLELE_PATH, 'DK_0911_v03_p_ctg.no_respective_h_contig_overlap.alleles'), header=None, names=['alleleOne', 'alleleTwo'], sep='\t')

overlapDf['matchType'] = 'overlap'
noOverlapDf['matchType'] = 'no_overlap'
diffContigDf['matchType'] = 'different_pcontig'

alleleDf = overlapDf.append([noOverlapDf, diffContigDf])

alleleDf['folder'] = alleleDf.alleleOne + '_' + alleleDf.alleleTwo
alleleDf.set_index('folder', inplace=True)

assert(len(alleleDf) == len(overlapDf) + len(noOverlapDf) + len(diffContigDf))

# %%
# Combine haplotig & primary contig fasta files for each allele type
# (protein, gene, CDS), and change headings so that they use id 
# (e.g. evm.model.pcontig_057.39) instead of locus tag (e.g. DK0911_16805).

os.chdir('/home/gamran/genome_analysis/Warrior/Richard/scripts')
# %run DK_0911_v03_dictionaries.ipynb
locusToIdDict = getLocusToIdDict()

def combineCtgFastaFiles(fastaFiles, fOut):
    '''combines fasta files and rewrites headings from locus tags
    (DK0911_16805) to id tags (evm.model.pcontig_057.39)'''
    with open(fOut, 'w') as outFile:
        for fastaFile in fastaFiles:
            with open(fastaFile, 'r') as inFile:
                for line in inFile:
                    if '>' in line:
                        line = '>' + locusToIdDict[line[1:-1]] + '\n'
                    outFile.write(line)
    return True

hProteinFasta = os.path.join(GENOME_PATH, 'DK_0911_v03_h_ctg.protein.fa')
pProteinFasta = os.path.join(GENOME_PATH, 'DK_0911_v03_p_ctg.protein.fa')
hGeneFasta = os.path.join(GENOME_PATH, 'DK_0911_v03_h_ctg.gene.fa')
pGeneFasta = os.path.join(GENOME_PATH, 'DK_0911_v03_p_ctg.gene.fa')
hCDSFasta = os.path.join(GENOME_PATH, 'DK_0911_v03_h_ctg.CDS.fa')
pCDSFasta = os.path.join(GENOME_PATH, 'DK_0911_v03_p_ctg.CDS.fa')

PH_PROTEIN_FASTA = os.path.join(GENOME_PATH, 'DK_0911_v03_ph_ctg.protein.fa')
PH_GENE_FASTA = os.path.join(GENOME_PATH, 'DK_0911_v03_ph_ctg.gene.fa')
PH_CDS_FASTA = os.path.join(GENOME_PATH, 'DK_0911_v03_ph_ctg.CDS.fa')

combineCtgFastaFiles([hProteinFasta, pProteinFasta], PH_PROTEIN_FASTA)
combineCtgFastaFiles([hGeneFasta, pGeneFasta], PH_GENE_FASTA)
combineCtgFastaFiles([hCDSFasta, pCDSFasta], PH_CDS_FASTA)
# Out:
# True

# %%
def getFastaDict(fastaFile):
    d = {}
    for gene in SeqIO.parse(fastaFile, 'fasta'):
        d[gene.id] = gene
    return d

SEQRECORD_PROTEIN_DICT = getFastaDict(PH_PROTEIN_FASTA)
SEQRECORD_GENE_DICT = getFastaDict(PH_GENE_FASTA)
SEQRECORD_CDS_DICT = getFastaDict(PH_CDS_FASTA)

# %%
# def getSpecificFasta(geneList, fastaFile):
#     '''Returns the fasta of gene in list as SeqIO object '''
#     # Ben's original code had CDS with '.model.' and 
#     # protein as '.TU.'
#     l = []
#     for gene in SeqIO.parse(fastaFile, 'fasta'):
#         if gene.id in geneList:
#             l.append(gene)
#     return l
# 
# def writeAllelicFasta(alleleOne, alleleTwo, alleleType, outPath):
#     '''writes fasta file containing fasta information for two alleles
#     in the outPath'''
#     assert(alleleType.upper() in ['CDS', 'GENE', 'PROTEIN'])
#     fastaFilePath = globals()['PH_' + alleleType.upper() + '_FASTA'] # e.g. alleleType = 'GENE', then fastaFile = PH_GENE_FASTA
#     specificFastaList = getSpecificFasta([alleleOne, alleleTwo], fastaFilePath)
#     with open(os.path.join(outPath, alleleType.lower() + '.fa'), 'w') as outFile:
#         SeqIO.write(specificFastaList, outFile, 'fasta')
#     return True

def writeAllelicFasta(alleleOne, alleleTwo, alleleType, outPath):
    '''writes fasta file containing fasta information for two alleles
    in the outPath'''
    assert(alleleType.upper() in ['CDS', 'GENE', 'PROTEIN'])
    
    seqRecordDict = globals()['SEQRECORD_' + alleleType.upper() + '_DICT']
    
    alleleSeqRecords = [seqRecordDict[alleleOne], seqRecordDict[alleleTwo]]
    with open(os.path.join(outPath, alleleType.lower() + '.fa'), 'w') as outFile:
        SeqIO.write(alleleSeqRecords, outFile, 'fasta')

    return True

def writeAlignmentScript(alleleOutPath, scriptLoc = os.path.join(PAML_PATH, 'paml_script.sh')):
    with open(scriptLoc, 'a') as outFile:
        print('cd %s' % alleleOutPath, file=outFile)
        print('/home/gamran/anaconda3/muscle3.8.31_i86linux64 -clwstrict -in protein.fa -out protein.aln', file=outFile)
        print('perl /home/gamran/anaconda3/pal2nal.v14/pal2nal.pl -output paml protein.aln cds.fa > cds_codon.aln', file=outFile)
        print('perl /home/gamran/anaconda3/pal2nal.v14/pal2nal.pl protein.aln cds.fa > cds_codon.clustal', file=outFile)
        print('cp %s/yn00.ctl ./' % PAML_PATH, file=outFile)
        print('/home/gamran/anaconda3/paml4.9g/bin/yn00', file=outFile)
    return True

# %%
def prepareAlignmentBashScript(scriptLoc = os.path.join(PAML_PATH, 'paml_script.sh')):
    with open(scriptLoc, 'w') as pamlScript:
        print('#!/bin/bash', file=pamlScript)

    for index, [alleleOne, alleleTwo, alleleType] in alleleDf.iterrows():

        alleleOutPath = os.path.join(PAML_PATH, '%s_%s' % (alleleOne, alleleTwo))
        if not os.path.exists(alleleOutPath):
            os.mkdir(os.path.join(PAML_PATH, '%s_%s' % (alleleOne, alleleTwo)))

        writeAllelicFasta(alleleOne, alleleTwo, 'CDS', alleleOutPath)
        writeAllelicFasta(alleleOne, alleleTwo, 'PROTEIN', alleleOutPath)

        writeAlignmentScript(alleleOutPath, os.path.join(PAML_PATH, 'paml_script.sh'))

# %%
# alleleDf['folder'] = alleleDf.alleleOne + '_' + alleleDf.alleleTwo
# alleleDf.index = alleleDf['folder']

# %%
def assignDistancesToAlleles(df, folder, alignmentFile, alleleType):
    '''Adds hamming and levenshtein distance columns to an allele pair
    (indexed by 'folder' name) in df'''
    assert(alleleType.upper() in ['PROTEIN', 'CDS', 'GENE'])
    seq1, seq2 = AlignIO.read(open(alignmentFile, 'r'), format='clustal', seq_count=2)
    seq1 = str(seq1.seq).upper()
    seq2 = str(seq2.seq).upper()
    assert(len(seq1) == len(seq2))
    df.loc[folder, alleleType.lower() + '_hamming'] = distance.hamming(seq1, seq2, normalized=True)
    df.loc[folder, alleleType.lower() + '_levenshtein'] = editdistance.eval(seq1, seq2)/len(seq1)
    return df

def assignDistancesToAllAlleles(alleleDf):
    count = 0
    total = len(alleleDf)
    percentDone = 0
    
    print("Calculating distances and adding them to the allele DataFrame...")
    
    for folder in alleleDf.index:

        proteinAlignmentFile = os.path.join(PAML_PATH, folder, 'protein.aln')
        alleleDf = assignDistancesToAlleles(alleleDf, folder, proteinAlignmentFile, 'PROTEIN')

        cdsAlignmentFile = os.path.join(PAML_PATH, folder, 'cds_codon.clustal')
        alleleDf = assignDistancesToAlleles(alleleDf, folder, cdsAlignmentFile, 'CDS')

        count += 1
        if round(count/total * 100) > percentDone:
            percentDone = round(count/total * 100)
            print("%s%% complete" % percentDone)
    return alleleDf

# %%
def parse_dNdS_to_df(line, alleleDf, folder, dNdS_label):
    dN = re.findall(r'dN = [-| ]?(.*) w', line)[0]
    dS = re.findall(r'dS = [-| ]?(.*) dN', line)[0]
    return assign_dNdS(dN, dS, alleleDf, folder, dNdS_label)

def assign_dNdS(dN, dS, alleleDf, folder, dNdS_label):
    if float(dS) > 0:
        alleleDf.loc[folder, dNdS_label] = float(dN)/float(dS)
    else:
        alleleDf.loc[folder, dNdS_label] = np.nan
    return alleleDf

def assign_dNdS_to_all_alleles(alleleDf):
    for folder in alleleDf.index:
        alleleYn = os.path.join(PAML_PATH, folder,'yn.out')
        with open(alleleYn, 'r') as ynOut:
            #now loop over the lines and parse out stuff
            for i, line in enumerate(ynOut):
                if line.startswith('seq. seq. ') and i > 0:
                    next(ynOut) # we want the line that is two after the line starting with 'seq. seq '
                    dataLine = next(ynOut)
                    dN = dataLine.split('+-')[0].rstrip().split(' ')[-1]
                    dS = dataLine.split('+-')[1].rstrip().split(' ')[-1]
                    alleleDf = assign_dNdS(dN, dS, alleleDf, folder, 'yn00_dN/dS')
                elif line.startswith('LWL85:') and 'nan' not in line:
                    alleleDf = parse_dNdS_to_df(line, alleleDf, folder, 'LWL85_dN/dS')
                elif line.startswith('LWL85m:') and 'nan' not in line:
                    alleleDf = parse_dNdS_to_df(line, alleleDf, folder, 'LWL85m_dN/dS')
                elif line.startswith('LPB93:') and 'nan' not in line:
                    alleleDf = parse_dNdS_to_df(line, alleleDf, folder, 'LPB93_dN/dS')
                else:
                    continue
    return alleleDf

# %%
def loadDfIfExists():

# %%
def main():
    prepareAlignmentBashScript(os.path.join(PAML_PATH, 'paml_script.sh'))
    
    # !bash {os.path.join(PAML_PATH, 'paml_script.sh')}
    
    distDfPath = os.path.join(BASE_OUT_PATH, 'distanceDf.df')
    if os.path.exists(distDfPath) and os.path.getsize(distDfPath) > 0:
        print("DataFrame with distance calculations at %s appears to have already been generated. Reading in this dataframe instead of re-generating it." % distDfPath)
        alleleDf = pd.read_csv(distDfPath, sep='\t', index_col=0)
    else:
        alleleDf = assignDistancesToAllAlleles(alleleDf)
        alleleDf.to_csv(distDfPath, sep='\t')
        pd.util.testing.assert_frame_equal(alleleDf, pd.read_csv(distDfPath, sep='\t', index_col=0))
    
    alleleDf = assign_dNdS_to_all_alleles(alleleDf)
    
    return alleleDf

# %%
if __name__ == "__main__":
    alleleDf = main()
# Out:
# DataFrame with distance calculations at /home/gamran/genome_analysis/Warrior/Richard/output/post_analysis/distanceDf.df appears to have already been generated. Reading in this dataframe instead of re-generating it.

# %%
alleleDf
# Out:
#                                                                      alleleOne  \
# folder
# evm.model.pcontig_000.1_evm.model.hcontig_000_0...     evm.model.pcontig_000.1
# evm.model.pcontig_000.100_evm.model.hcontig_000...   evm.model.pcontig_000.100
# evm.model.pcontig_000.1000_evm.model.hcontig_00...  evm.model.pcontig_000.1000
# evm.model.pcontig_000.1001_evm.model.hcontig_00...  evm.model.pcontig_000.1001
# evm.model.pcontig_000.1002_evm.model.hcontig_00...  evm.model.pcontig_000.1002
# evm.model.pcontig_000.1003_evm.model.hcontig_00...  evm.model.pcontig_000.1003
# evm.model.pcontig_000.1005_evm.model.hcontig_00...  evm.model.pcontig_000.1005
# evm.model.pcontig_000.1007_evm.model.hcontig_00...  evm.model.pcontig_000.1007
# evm.model.pcontig_000.1008_evm.model.hcontig_00...  evm.model.pcontig_000.1008
# evm.model.pcontig_000.1009_evm.model.hcontig_00...  evm.model.pcontig_000.1009
# evm.model.pcontig_000.101_evm.model.hcontig_000...   evm.model.pcontig_000.101
# evm.model.pcontig_000.1010_evm.model.hcontig_00...  evm.model.pcontig_000.1010
# evm.model.pcontig_000.1011_evm.model.hcontig_00...  evm.model.pcontig_000.1011
# evm.model.pcontig_000.1012_evm.model.hcontig_00...  evm.model.pcontig_000.1012
# evm.model.pcontig_000.1014_evm.model.hcontig_00...  evm.model.pcontig_000.1014
# evm.model.pcontig_000.1015_evm.model.hcontig_00...  evm.model.pcontig_000.1015
# evm.model.pcontig_000.1016_evm.model.hcontig_00...  evm.model.pcontig_000.1016
# evm.model.pcontig_000.1019_evm.model.hcontig_00...  evm.model.pcontig_000.1019
# evm.model.pcontig_000.1020_evm.model.hcontig_00...  evm.model.pcontig_000.1020
# evm.model.pcontig_000.1021_evm.model.hcontig_00...  evm.model.pcontig_000.1021
# evm.model.pcontig_000.1022_evm.model.hcontig_00...  evm.model.pcontig_000.1022
# evm.model.pcontig_000.1023_evm.model.hcontig_00...  evm.model.pcontig_000.1023
# evm.model.pcontig_000.1024_evm.model.hcontig_00...  evm.model.pcontig_000.1024
# evm.model.pcontig_000.1026_evm.model.hcontig_00...  evm.model.pcontig_000.1026
# evm.model.pcontig_000.1027_evm.model.hcontig_00...  evm.model.pcontig_000.1027
# evm.model.pcontig_000.1028_evm.model.hcontig_00...  evm.model.pcontig_000.1028
# evm.model.pcontig_000.1029_evm.model.hcontig_00...  evm.model.pcontig_000.1029
# evm.model.pcontig_000.103_evm.model.hcontig_000...   evm.model.pcontig_000.103
# evm.model.pcontig_000.1030_evm.model.hcontig_00...  evm.model.pcontig_000.1030
# evm.model.pcontig_000.1031_evm.model.hcontig_00...  evm.model.pcontig_000.1031
# ...                                                                        ...
# evm.model.pcontig_104.1_evm.model.hcontig_021_0...     evm.model.pcontig_104.1
# evm.model.pcontig_104.2_evm.model.hcontig_004_0...     evm.model.pcontig_104.2
# evm.model.pcontig_104.3_evm.model.hcontig_004_0...     evm.model.pcontig_104.3
# evm.model.pcontig_104.4_evm.model.hcontig_026_0...     evm.model.pcontig_104.4
# evm.model.pcontig_104.4_evm.model.hcontig_089_0...     evm.model.pcontig_104.4
# evm.model.pcontig_105.1_evm.model.hcontig_011_0...     evm.model.pcontig_105.1
# evm.model.pcontig_106.1_evm.model.hcontig_018_0...     evm.model.pcontig_106.1
# evm.model.pcontig_107.1_evm.model.hcontig_003_0...     evm.model.pcontig_107.1
# evm.model.pcontig_107.2_evm.model.hcontig_050_0...     evm.model.pcontig_107.2
# evm.model.pcontig_107.3_evm.model.hcontig_006_0...     evm.model.pcontig_107.3
# evm.model.pcontig_107.4_evm.model.hcontig_009_0...     evm.model.pcontig_107.4
# evm.model.pcontig_107.5_evm.model.hcontig_003_0...     evm.model.pcontig_107.5
# evm.model.pcontig_107.7_evm.model.hcontig_011_0...     evm.model.pcontig_107.7
# evm.model.pcontig_109.1_evm.model.hcontig_003_0...     evm.model.pcontig_109.1
# evm.model.pcontig_109.2_evm.model.hcontig_003_0...     evm.model.pcontig_109.2
# evm.model.pcontig_109.3_evm.model.hcontig_003_0...     evm.model.pcontig_109.3
# evm.model.pcontig_109.4_evm.model.hcontig_003_0...     evm.model.pcontig_109.4
# evm.model.pcontig_109.5_evm.model.hcontig_006_0...     evm.model.pcontig_109.5
# evm.model.pcontig_109.6_evm.model.hcontig_006_0...     evm.model.pcontig_109.6
# evm.model.pcontig_109.7_evm.model.hcontig_006_0...     evm.model.pcontig_109.7
# evm.model.pcontig_109.8_evm.model.hcontig_003_0...     evm.model.pcontig_109.8
# evm.model.pcontig_110.1_evm.model.hcontig_065_0...     evm.model.pcontig_110.1
# evm.model.pcontig_110.2_evm.model.hcontig_068_0...     evm.model.pcontig_110.2
# evm.model.pcontig_110.3_evm.model.hcontig_068_0...     evm.model.pcontig_110.3
# evm.model.pcontig_110.4_evm.model.hcontig_068_0...     evm.model.pcontig_110.4
# evm.model.pcontig_110.6_evm.model.hcontig_068_0...     evm.model.pcontig_110.6
# evm.model.pcontig_110.6_evm.model.hcontig_065_0...     evm.model.pcontig_110.6
# evm.model.pcontig_110.7_evm.model.hcontig_060_0...     evm.model.pcontig_110.7
# evm.model.pcontig_110.8_evm.model.hcontig_057_0...     evm.model.pcontig_110.8
# evm.model.pcontig_110.9_evm.model.hcontig_068_0...     evm.model.pcontig_110.9
#
#                                                                        alleleTwo  \
# folder
# evm.model.pcontig_000.1_evm.model.hcontig_000_0...   evm.model.hcontig_000_024.1
# evm.model.pcontig_000.100_evm.model.hcontig_000...   evm.model.hcontig_000_058.5
# evm.model.pcontig_000.1000_evm.model.hcontig_00...  evm.model.hcontig_000_078.13
# evm.model.pcontig_000.1001_evm.model.hcontig_00...  evm.model.hcontig_000_078.18
# evm.model.pcontig_000.1002_evm.model.hcontig_00...  evm.model.hcontig_000_078.16
# evm.model.pcontig_000.1003_evm.model.hcontig_00...  evm.model.hcontig_000_078.16
# evm.model.pcontig_000.1005_evm.model.hcontig_00...  evm.model.hcontig_000_078.13
# evm.model.pcontig_000.1007_evm.model.hcontig_00...  evm.model.hcontig_000_078.16
# evm.model.pcontig_000.1008_evm.model.hcontig_00...   evm.model.hcontig_000_060.2
# evm.model.pcontig_000.1009_evm.model.hcontig_00...   evm.model.hcontig_000_060.3
# evm.model.pcontig_000.101_evm.model.hcontig_000...   evm.model.hcontig_000_058.6
# evm.model.pcontig_000.1010_evm.model.hcontig_00...   evm.model.hcontig_000_060.4
# evm.model.pcontig_000.1011_evm.model.hcontig_00...   evm.model.hcontig_000_060.5
# evm.model.pcontig_000.1012_evm.model.hcontig_00...  evm.model.hcontig_000_078.18
# evm.model.pcontig_000.1014_evm.model.hcontig_00...   evm.model.hcontig_000_060.7
# evm.model.pcontig_000.1015_evm.model.hcontig_00...  evm.model.hcontig_000_078.20
# evm.model.pcontig_000.1016_evm.model.hcontig_00...  evm.model.hcontig_000_078.21
# evm.model.pcontig_000.1019_evm.model.hcontig_00...  evm.model.hcontig_000_078.22
# evm.model.pcontig_000.1020_evm.model.hcontig_00...  evm.model.hcontig_000_078.24
# evm.model.pcontig_000.1021_evm.model.hcontig_00...  evm.model.hcontig_000_078.25
# evm.model.pcontig_000.1022_evm.model.hcontig_00...  evm.model.hcontig_000_078.26
# evm.model.pcontig_000.1023_evm.model.hcontig_00...  evm.model.hcontig_000_078.27
# evm.model.pcontig_000.1024_evm.model.hcontig_00...  evm.model.hcontig_000_078.28
# evm.model.pcontig_000.1026_evm.model.hcontig_00...  evm.model.hcontig_000_078.29
# evm.model.pcontig_000.1027_evm.model.hcontig_00...   evm.model.hcontig_000_061.2
# evm.model.pcontig_000.1028_evm.model.hcontig_00...  evm.model.hcontig_000_078.33
# evm.model.pcontig_000.1029_evm.model.hcontig_00...  evm.model.hcontig_000_078.38
# evm.model.pcontig_000.103_evm.model.hcontig_000...  evm.model.hcontig_000_046.22
# evm.model.pcontig_000.1030_evm.model.hcontig_00...  evm.model.hcontig_000_078.39
# evm.model.pcontig_000.1031_evm.model.hcontig_00...  evm.model.hcontig_000_078.40
# ...                                                                          ...
# evm.model.pcontig_104.1_evm.model.hcontig_021_0...   evm.model.hcontig_021_003.9
# evm.model.pcontig_104.2_evm.model.hcontig_004_0...   evm.model.hcontig_004_011.1
# evm.model.pcontig_104.3_evm.model.hcontig_004_0...   evm.model.hcontig_004_011.1
# evm.model.pcontig_104.4_evm.model.hcontig_026_0...   evm.model.hcontig_026_016.1
# evm.model.pcontig_104.4_evm.model.hcontig_089_0...   evm.model.hcontig_089_001.1
# evm.model.pcontig_105.1_evm.model.hcontig_011_0...  evm.model.hcontig_011_035.25
# evm.model.pcontig_106.1_evm.model.hcontig_018_0...   evm.model.hcontig_018_013.1
# evm.model.pcontig_107.1_evm.model.hcontig_003_0...  evm.model.hcontig_003_044.14
# evm.model.pcontig_107.2_evm.model.hcontig_050_0...   evm.model.hcontig_050_005.9
# evm.model.pcontig_107.3_evm.model.hcontig_006_0...  evm.model.hcontig_006_043.10
# evm.model.pcontig_107.4_evm.model.hcontig_009_0...  evm.model.hcontig_009_035.22
# evm.model.pcontig_107.5_evm.model.hcontig_003_0...   evm.model.hcontig_003_010.1
# evm.model.pcontig_107.7_evm.model.hcontig_011_0...  evm.model.hcontig_011_030.58
# evm.model.pcontig_109.1_evm.model.hcontig_003_0...   evm.model.hcontig_003_020.6
# evm.model.pcontig_109.2_evm.model.hcontig_003_0...   evm.model.hcontig_003_020.5
# evm.model.pcontig_109.3_evm.model.hcontig_003_0...   evm.model.hcontig_003_020.4
# evm.model.pcontig_109.4_evm.model.hcontig_003_0...   evm.model.hcontig_003_020.3
# evm.model.pcontig_109.5_evm.model.hcontig_006_0...   evm.model.hcontig_006_023.5
# evm.model.pcontig_109.6_evm.model.hcontig_006_0...   evm.model.hcontig_006_023.5
# evm.model.pcontig_109.7_evm.model.hcontig_006_0...  evm.model.hcontig_006_030.10
# evm.model.pcontig_109.8_evm.model.hcontig_003_0...   evm.model.hcontig_003_020.2
# evm.model.pcontig_110.1_evm.model.hcontig_065_0...   evm.model.hcontig_065_004.2
# evm.model.pcontig_110.2_evm.model.hcontig_068_0...  evm.model.hcontig_068_006.26
# evm.model.pcontig_110.3_evm.model.hcontig_068_0...  evm.model.hcontig_068_006.27
# evm.model.pcontig_110.4_evm.model.hcontig_068_0...  evm.model.hcontig_068_006.28
# evm.model.pcontig_110.6_evm.model.hcontig_068_0...  evm.model.hcontig_068_006.29
# evm.model.pcontig_110.6_evm.model.hcontig_065_0...   evm.model.hcontig_065_003.6
# evm.model.pcontig_110.7_evm.model.hcontig_060_0...  evm.model.hcontig_060_006.27
# evm.model.pcontig_110.8_evm.model.hcontig_057_0...   evm.model.hcontig_057_004.7
# evm.model.pcontig_110.9_evm.model.hcontig_068_0...  evm.model.hcontig_068_006.30
#
#                                                             matchType  \
# folder
# evm.model.pcontig_000.1_evm.model.hcontig_000_0...            overlap
# evm.model.pcontig_000.100_evm.model.hcontig_000...            overlap
# evm.model.pcontig_000.1000_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1001_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1002_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1003_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1005_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1007_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1008_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1009_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.101_evm.model.hcontig_000...            overlap
# evm.model.pcontig_000.1010_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1011_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1012_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1014_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1015_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1016_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1019_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1020_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1021_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1022_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1023_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1024_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1026_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1027_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1028_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1029_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.103_evm.model.hcontig_000...            overlap
# evm.model.pcontig_000.1030_evm.model.hcontig_00...            overlap
# evm.model.pcontig_000.1031_evm.model.hcontig_00...            overlap
# ...                                                               ...
# evm.model.pcontig_104.1_evm.model.hcontig_021_0...  different_pcontig
# evm.model.pcontig_104.2_evm.model.hcontig_004_0...  different_pcontig
# evm.model.pcontig_104.3_evm.model.hcontig_004_0...  different_pcontig
# evm.model.pcontig_104.4_evm.model.hcontig_026_0...  different_pcontig
# evm.model.pcontig_104.4_evm.model.hcontig_089_0...  different_pcontig
# evm.model.pcontig_105.1_evm.model.hcontig_011_0...  different_pcontig
# evm.model.pcontig_106.1_evm.model.hcontig_018_0...  different_pcontig
# evm.model.pcontig_107.1_evm.model.hcontig_003_0...  different_pcontig
# evm.model.pcontig_107.2_evm.model.hcontig_050_0...  different_pcontig
# evm.model.pcontig_107.3_evm.model.hcontig_006_0...  different_pcontig
# evm.model.pcontig_107.4_evm.model.hcontig_009_0...  different_pcontig
# evm.model.pcontig_107.5_evm.model.hcontig_003_0...  different_pcontig
# evm.model.pcontig_107.7_evm.model.hcontig_011_0...  different_pcontig
# evm.model.pcontig_109.1_evm.model.hcontig_003_0...  different_pcontig
# evm.model.pcontig_109.2_evm.model.hcontig_003_0...  different_pcontig
# evm.model.pcontig_109.3_evm.model.hcontig_003_0...  different_pcontig
# evm.model.pcontig_109.4_evm.model.hcontig_003_0...  different_pcontig
# evm.model.pcontig_109.5_evm.model.hcontig_006_0...  different_pcontig
# evm.model.pcontig_109.6_evm.model.hcontig_006_0...  different_pcontig
# evm.model.pcontig_109.7_evm.model.hcontig_006_0...  different_pcontig
# evm.model.pcontig_109.8_evm.model.hcontig_003_0...  different_pcontig
# evm.model.pcontig_110.1_evm.model.hcontig_065_0...  different_pcontig
# evm.model.pcontig_110.2_evm.model.hcontig_068_0...  different_pcontig
# evm.model.pcontig_110.3_evm.model.hcontig_068_0...  different_pcontig
# evm.model.pcontig_110.4_evm.model.hcontig_068_0...  different_pcontig
# evm.model.pcontig_110.6_evm.model.hcontig_068_0...  different_pcontig
# evm.model.pcontig_110.6_evm.model.hcontig_065_0...  different_pcontig
# evm.model.pcontig_110.7_evm.model.hcontig_060_0...  different_pcontig
# evm.model.pcontig_110.8_evm.model.hcontig_057_0...  different_pcontig
# evm.model.pcontig_110.9_evm.model.hcontig_068_0...  different_pcontig
#
#                                                     protein_hamming  \
# folder
# evm.model.pcontig_000.1_evm.model.hcontig_000_0...         0.000000
# evm.model.pcontig_000.100_evm.model.hcontig_000...         0.000000
# evm.model.pcontig_000.1000_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1001_evm.model.hcontig_00...         0.913043
# evm.model.pcontig_000.1002_evm.model.hcontig_00...         0.918367
# evm.model.pcontig_000.1003_evm.model.hcontig_00...         0.887892
# evm.model.pcontig_000.1005_evm.model.hcontig_00...         0.709677
# evm.model.pcontig_000.1007_evm.model.hcontig_00...         0.111111
# evm.model.pcontig_000.1008_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1009_evm.model.hcontig_00...         0.012422
# evm.model.pcontig_000.101_evm.model.hcontig_000...         0.000000
# evm.model.pcontig_000.1010_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1011_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1012_evm.model.hcontig_00...         0.009153
# evm.model.pcontig_000.1014_evm.model.hcontig_00...         0.389578
# evm.model.pcontig_000.1015_evm.model.hcontig_00...         0.007576
# evm.model.pcontig_000.1016_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1019_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1020_evm.model.hcontig_00...         0.016835
# evm.model.pcontig_000.1021_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1022_evm.model.hcontig_00...         0.018182
# evm.model.pcontig_000.1023_evm.model.hcontig_00...         0.019169
# evm.model.pcontig_000.1024_evm.model.hcontig_00...         0.195767
# evm.model.pcontig_000.1026_evm.model.hcontig_00...         0.503559
# evm.model.pcontig_000.1027_evm.model.hcontig_00...         0.255906
# evm.model.pcontig_000.1028_evm.model.hcontig_00...         0.186047
# evm.model.pcontig_000.1029_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.103_evm.model.hcontig_000...         0.256274
# evm.model.pcontig_000.1030_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1031_evm.model.hcontig_00...         0.250000
# ...                                                             ...
# evm.model.pcontig_104.1_evm.model.hcontig_021_0...         0.205882
# evm.model.pcontig_104.2_evm.model.hcontig_004_0...         0.682697
# evm.model.pcontig_104.3_evm.model.hcontig_004_0...         0.511645
# evm.model.pcontig_104.4_evm.model.hcontig_026_0...         0.466019
# evm.model.pcontig_104.4_evm.model.hcontig_089_0...         0.519651
# evm.model.pcontig_105.1_evm.model.hcontig_011_0...         0.596257
# evm.model.pcontig_106.1_evm.model.hcontig_018_0...         0.388809
# evm.model.pcontig_107.1_evm.model.hcontig_003_0...         0.887543
# evm.model.pcontig_107.2_evm.model.hcontig_050_0...         0.128205
# evm.model.pcontig_107.3_evm.model.hcontig_006_0...         0.662534
# evm.model.pcontig_107.4_evm.model.hcontig_009_0...         0.421599
# evm.model.pcontig_107.5_evm.model.hcontig_003_0...         0.698878
# evm.model.pcontig_107.7_evm.model.hcontig_011_0...         0.938903
# evm.model.pcontig_109.1_evm.model.hcontig_003_0...         0.358382
# evm.model.pcontig_109.2_evm.model.hcontig_003_0...         0.055556
# evm.model.pcontig_109.3_evm.model.hcontig_003_0...         0.000000
# evm.model.pcontig_109.4_evm.model.hcontig_003_0...         0.000000
# evm.model.pcontig_109.5_evm.model.hcontig_006_0...         0.683773
# evm.model.pcontig_109.6_evm.model.hcontig_006_0...         0.776699
# evm.model.pcontig_109.7_evm.model.hcontig_006_0...         0.536534
# evm.model.pcontig_109.8_evm.model.hcontig_003_0...         0.758278
# evm.model.pcontig_110.1_evm.model.hcontig_065_0...         0.603524
# evm.model.pcontig_110.2_evm.model.hcontig_068_0...         0.000000
# evm.model.pcontig_110.3_evm.model.hcontig_068_0...         0.110778
# evm.model.pcontig_110.4_evm.model.hcontig_068_0...         0.000000
# evm.model.pcontig_110.6_evm.model.hcontig_068_0...         0.330935
# evm.model.pcontig_110.6_evm.model.hcontig_065_0...         0.330935
# evm.model.pcontig_110.7_evm.model.hcontig_060_0...         0.320557
# evm.model.pcontig_110.8_evm.model.hcontig_057_0...         0.680135
# evm.model.pcontig_110.9_evm.model.hcontig_068_0...         0.720063
#
#                                                     protein_levenshtein  \
# folder
# evm.model.pcontig_000.1_evm.model.hcontig_000_0...             0.000000
# evm.model.pcontig_000.100_evm.model.hcontig_000...             0.000000
# evm.model.pcontig_000.1000_evm.model.hcontig_00...             0.000000
# evm.model.pcontig_000.1001_evm.model.hcontig_00...             0.903890
# evm.model.pcontig_000.1002_evm.model.hcontig_00...             0.916100
# evm.model.pcontig_000.1003_evm.model.hcontig_00...             0.885650
# evm.model.pcontig_000.1005_evm.model.hcontig_00...             0.701613
# evm.model.pcontig_000.1007_evm.model.hcontig_00...             0.111111
# evm.model.pcontig_000.1008_evm.model.hcontig_00...             0.000000
# evm.model.pcontig_000.1009_evm.model.hcontig_00...             0.012422
# evm.model.pcontig_000.101_evm.model.hcontig_000...             0.000000
# evm.model.pcontig_000.1010_evm.model.hcontig_00...             0.000000
# evm.model.pcontig_000.1011_evm.model.hcontig_00...             0.000000
# evm.model.pcontig_000.1012_evm.model.hcontig_00...             0.009153
# evm.model.pcontig_000.1014_evm.model.hcontig_00...             0.387097
# evm.model.pcontig_000.1015_evm.model.hcontig_00...             0.007576
# evm.model.pcontig_000.1016_evm.model.hcontig_00...             0.000000
# evm.model.pcontig_000.1019_evm.model.hcontig_00...             0.000000
# evm.model.pcontig_000.1020_evm.model.hcontig_00...             0.016835
# evm.model.pcontig_000.1021_evm.model.hcontig_00...             0.000000
# evm.model.pcontig_000.1022_evm.model.hcontig_00...             0.018182
# evm.model.pcontig_000.1023_evm.model.hcontig_00...             0.019169
# evm.model.pcontig_000.1024_evm.model.hcontig_00...             0.195767
# evm.model.pcontig_000.1026_evm.model.hcontig_00...             0.503559
# evm.model.pcontig_000.1027_evm.model.hcontig_00...             0.255906
# evm.model.pcontig_000.1028_evm.model.hcontig_00...             0.186047
# evm.model.pcontig_000.1029_evm.model.hcontig_00...             0.000000
# evm.model.pcontig_000.103_evm.model.hcontig_000...             0.255513
# evm.model.pcontig_000.1030_evm.model.hcontig_00...             0.000000
# evm.model.pcontig_000.1031_evm.model.hcontig_00...             0.250000
# ...                                                                 ...
# evm.model.pcontig_104.1_evm.model.hcontig_021_0...             0.205882
# evm.model.pcontig_104.2_evm.model.hcontig_004_0...             0.682697
# evm.model.pcontig_104.3_evm.model.hcontig_004_0...             0.511645
# evm.model.pcontig_104.4_evm.model.hcontig_026_0...             0.466019
# evm.model.pcontig_104.4_evm.model.hcontig_089_0...             0.519651
# evm.model.pcontig_105.1_evm.model.hcontig_011_0...             0.596257
# evm.model.pcontig_106.1_evm.model.hcontig_018_0...             0.388092
# evm.model.pcontig_107.1_evm.model.hcontig_003_0...             0.887543
# evm.model.pcontig_107.2_evm.model.hcontig_050_0...             0.128205
# evm.model.pcontig_107.3_evm.model.hcontig_006_0...             0.662534
# evm.model.pcontig_107.4_evm.model.hcontig_009_0...             0.421599
# evm.model.pcontig_107.5_evm.model.hcontig_003_0...             0.698878
# evm.model.pcontig_107.7_evm.model.hcontig_011_0...             0.938279
# evm.model.pcontig_109.1_evm.model.hcontig_003_0...             0.358382
# evm.model.pcontig_109.2_evm.model.hcontig_003_0...             0.055556
# evm.model.pcontig_109.3_evm.model.hcontig_003_0...             0.000000
# evm.model.pcontig_109.4_evm.model.hcontig_003_0...             0.000000
# evm.model.pcontig_109.5_evm.model.hcontig_006_0...             0.682386
# evm.model.pcontig_109.6_evm.model.hcontig_006_0...             0.776699
# evm.model.pcontig_109.7_evm.model.hcontig_006_0...             0.536534
# evm.model.pcontig_109.8_evm.model.hcontig_003_0...             0.758278
# evm.model.pcontig_110.1_evm.model.hcontig_065_0...             0.603524
# evm.model.pcontig_110.2_evm.model.hcontig_068_0...             0.000000
# evm.model.pcontig_110.3_evm.model.hcontig_068_0...             0.110778
# evm.model.pcontig_110.4_evm.model.hcontig_068_0...             0.000000
# evm.model.pcontig_110.6_evm.model.hcontig_068_0...             0.330935
# evm.model.pcontig_110.6_evm.model.hcontig_065_0...             0.330935
# evm.model.pcontig_110.7_evm.model.hcontig_060_0...             0.320557
# evm.model.pcontig_110.8_evm.model.hcontig_057_0...             0.680135
# evm.model.pcontig_110.9_evm.model.hcontig_068_0...             0.720063
#
#                                                     cds_hamming  \
# folder
# evm.model.pcontig_000.1_evm.model.hcontig_000_0...     0.000000
# evm.model.pcontig_000.100_evm.model.hcontig_000...     0.000000
# evm.model.pcontig_000.1000_evm.model.hcontig_00...     0.003333
# evm.model.pcontig_000.1001_evm.model.hcontig_00...     0.848970
# evm.model.pcontig_000.1002_evm.model.hcontig_00...     0.876795
# evm.model.pcontig_000.1003_evm.model.hcontig_00...     0.845291
# evm.model.pcontig_000.1005_evm.model.hcontig_00...     0.634409
# evm.model.pcontig_000.1007_evm.model.hcontig_00...     0.109599
# evm.model.pcontig_000.1008_evm.model.hcontig_00...     0.002976
# evm.model.pcontig_000.1009_evm.model.hcontig_00...     0.006211
# evm.model.pcontig_000.101_evm.model.hcontig_000...     0.000000
# evm.model.pcontig_000.1010_evm.model.hcontig_00...     0.002268
# evm.model.pcontig_000.1011_evm.model.hcontig_00...     0.002331
# evm.model.pcontig_000.1012_evm.model.hcontig_00...     0.003051
# evm.model.pcontig_000.1014_evm.model.hcontig_00...     0.365591
# evm.model.pcontig_000.1015_evm.model.hcontig_00...     0.002525
# evm.model.pcontig_000.1016_evm.model.hcontig_00...     0.000000
# evm.model.pcontig_000.1019_evm.model.hcontig_00...     0.000307
# evm.model.pcontig_000.1020_evm.model.hcontig_00...     0.020763
# evm.model.pcontig_000.1021_evm.model.hcontig_00...     0.000277
# evm.model.pcontig_000.1022_evm.model.hcontig_00...     0.021212
# evm.model.pcontig_000.1023_evm.model.hcontig_00...     0.031949
# evm.model.pcontig_000.1024_evm.model.hcontig_00...     0.190476
# evm.model.pcontig_000.1026_evm.model.hcontig_00...     0.475682
# evm.model.pcontig_000.1027_evm.model.hcontig_00...     0.255906
# evm.model.pcontig_000.1028_evm.model.hcontig_00...     0.172757
# evm.model.pcontig_000.1029_evm.model.hcontig_00...     0.007407
# evm.model.pcontig_000.103_evm.model.hcontig_000...     0.244867
# evm.model.pcontig_000.1030_evm.model.hcontig_00...     0.000000
# evm.model.pcontig_000.1031_evm.model.hcontig_00...     0.223577
# ...                                                         ...
# evm.model.pcontig_104.1_evm.model.hcontig_021_0...     0.078431
# evm.model.pcontig_104.2_evm.model.hcontig_004_0...     0.683193
# evm.model.pcontig_104.3_evm.model.hcontig_004_0...     0.543668
# evm.model.pcontig_104.4_evm.model.hcontig_026_0...     0.466019
# evm.model.pcontig_104.4_evm.model.hcontig_089_0...     0.519651
# evm.model.pcontig_105.1_evm.model.hcontig_011_0...     0.535651
# evm.model.pcontig_106.1_evm.model.hcontig_018_0...     0.447154
# evm.model.pcontig_107.1_evm.model.hcontig_003_0...     0.886390
# evm.model.pcontig_107.2_evm.model.hcontig_050_0...     0.119658
# evm.model.pcontig_107.3_evm.model.hcontig_006_0...     0.671488
# evm.model.pcontig_107.4_evm.model.hcontig_009_0...     0.438214
# evm.model.pcontig_107.5_evm.model.hcontig_003_0...     0.698016
# evm.model.pcontig_107.7_evm.model.hcontig_011_0...     0.902951
# evm.model.pcontig_109.1_evm.model.hcontig_003_0...     0.335260
# evm.model.pcontig_109.2_evm.model.hcontig_003_0...     0.048611
# evm.model.pcontig_109.3_evm.model.hcontig_003_0...     0.000000
# evm.model.pcontig_109.4_evm.model.hcontig_003_0...     0.000000
# evm.model.pcontig_109.5_evm.model.hcontig_006_0...     0.679149
# evm.model.pcontig_109.6_evm.model.hcontig_006_0...     0.776237
# evm.model.pcontig_109.7_evm.model.hcontig_006_0...     0.535839
# evm.model.pcontig_109.8_evm.model.hcontig_003_0...     0.755408
# evm.model.pcontig_110.1_evm.model.hcontig_065_0...     0.603524
# evm.model.pcontig_110.2_evm.model.hcontig_068_0...     0.000000
# evm.model.pcontig_110.3_evm.model.hcontig_068_0...     0.110778
# evm.model.pcontig_110.4_evm.model.hcontig_068_0...     0.000000
# evm.model.pcontig_110.6_evm.model.hcontig_068_0...     0.321343
# evm.model.pcontig_110.6_evm.model.hcontig_065_0...     0.321343
# evm.model.pcontig_110.7_evm.model.hcontig_060_0...     0.407666
# evm.model.pcontig_110.8_evm.model.hcontig_057_0...     0.680696
# evm.model.pcontig_110.9_evm.model.hcontig_068_0...     0.719535
#
#                                                     cds_levenshtein  \
# folder
# evm.model.pcontig_000.1_evm.model.hcontig_000_0...         0.000000
# evm.model.pcontig_000.100_evm.model.hcontig_000...         0.000000
# evm.model.pcontig_000.1000_evm.model.hcontig_00...         0.003333
# evm.model.pcontig_000.1001_evm.model.hcontig_00...         0.811594
# evm.model.pcontig_000.1002_evm.model.hcontig_00...         0.848828
# evm.model.pcontig_000.1003_evm.model.hcontig_00...         0.816891
# evm.model.pcontig_000.1005_evm.model.hcontig_00...         0.602151
# evm.model.pcontig_000.1007_evm.model.hcontig_00...         0.108088
# evm.model.pcontig_000.1008_evm.model.hcontig_00...         0.002976
# evm.model.pcontig_000.1009_evm.model.hcontig_00...         0.006211
# evm.model.pcontig_000.101_evm.model.hcontig_000...         0.000000
# evm.model.pcontig_000.1010_evm.model.hcontig_00...         0.002268
# evm.model.pcontig_000.1011_evm.model.hcontig_00...         0.002331
# evm.model.pcontig_000.1012_evm.model.hcontig_00...         0.003051
# evm.model.pcontig_000.1014_evm.model.hcontig_00...         0.309347
# evm.model.pcontig_000.1015_evm.model.hcontig_00...         0.002525
# evm.model.pcontig_000.1016_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1019_evm.model.hcontig_00...         0.000307
# evm.model.pcontig_000.1020_evm.model.hcontig_00...         0.020763
# evm.model.pcontig_000.1021_evm.model.hcontig_00...         0.000277
# evm.model.pcontig_000.1022_evm.model.hcontig_00...         0.021212
# evm.model.pcontig_000.1023_evm.model.hcontig_00...         0.031949
# evm.model.pcontig_000.1024_evm.model.hcontig_00...         0.167549
# evm.model.pcontig_000.1026_evm.model.hcontig_00...         0.413701
# evm.model.pcontig_000.1027_evm.model.hcontig_00...         0.255906
# evm.model.pcontig_000.1028_evm.model.hcontig_00...         0.172757
# evm.model.pcontig_000.1029_evm.model.hcontig_00...         0.007407
# evm.model.pcontig_000.103_evm.model.hcontig_000...         0.239544
# evm.model.pcontig_000.1030_evm.model.hcontig_00...         0.000000
# evm.model.pcontig_000.1031_evm.model.hcontig_00...         0.170732
# ...                                                             ...
# evm.model.pcontig_104.1_evm.model.hcontig_021_0...         0.078431
# evm.model.pcontig_104.2_evm.model.hcontig_004_0...         0.682862
# evm.model.pcontig_104.3_evm.model.hcontig_004_0...         0.543668
# evm.model.pcontig_104.4_evm.model.hcontig_026_0...         0.466019
# evm.model.pcontig_104.4_evm.model.hcontig_089_0...         0.519651
# evm.model.pcontig_105.1_evm.model.hcontig_011_0...         0.517825
# evm.model.pcontig_106.1_evm.model.hcontig_018_0...         0.438785
# evm.model.pcontig_107.1_evm.model.hcontig_003_0...         0.886390
# evm.model.pcontig_107.2_evm.model.hcontig_050_0...         0.119658
# evm.model.pcontig_107.3_evm.model.hcontig_006_0...         0.659320
# evm.model.pcontig_107.4_evm.model.hcontig_009_0...         0.437175
# evm.model.pcontig_107.5_evm.model.hcontig_003_0...         0.697153
# evm.model.pcontig_107.7_evm.model.hcontig_011_0...         0.882170
# evm.model.pcontig_109.1_evm.model.hcontig_003_0...         0.296724
# evm.model.pcontig_109.2_evm.model.hcontig_003_0...         0.033565
# evm.model.pcontig_109.3_evm.model.hcontig_003_0...         0.000000
# evm.model.pcontig_109.4_evm.model.hcontig_003_0...         0.000000
# evm.model.pcontig_109.5_evm.model.hcontig_006_0...         0.674064
# evm.model.pcontig_109.6_evm.model.hcontig_006_0...         0.776237
# evm.model.pcontig_109.7_evm.model.hcontig_006_0...         0.533055
# evm.model.pcontig_109.8_evm.model.hcontig_003_0...         0.755408
# evm.model.pcontig_110.1_evm.model.hcontig_065_0...         0.603524
# evm.model.pcontig_110.2_evm.model.hcontig_068_0...         0.000000
# evm.model.pcontig_110.3_evm.model.hcontig_068_0...         0.110778
# evm.model.pcontig_110.4_evm.model.hcontig_068_0...         0.000000
# evm.model.pcontig_110.6_evm.model.hcontig_068_0...         0.321343
# evm.model.pcontig_110.6_evm.model.hcontig_065_0...         0.321343
# evm.model.pcontig_110.7_evm.model.hcontig_060_0...         0.407666
# evm.model.pcontig_110.8_evm.model.hcontig_057_0...         0.680696
# evm.model.pcontig_110.9_evm.model.hcontig_068_0...         0.718477
#
#                                                     yn00_dN/dS  LWL85_dN/dS  \
# folder
# evm.model.pcontig_000.1_evm.model.hcontig_000_0...         NaN          NaN
# evm.model.pcontig_000.100_evm.model.hcontig_000...         NaN          NaN
# evm.model.pcontig_000.1000_evm.model.hcontig_00...   -0.000000     0.000000
# evm.model.pcontig_000.1001_evm.model.hcontig_00...    0.556251          NaN
# evm.model.pcontig_000.1002_evm.model.hcontig_00...    0.258478          NaN
# evm.model.pcontig_000.1003_evm.model.hcontig_00...    0.212720          NaN
# evm.model.pcontig_000.1005_evm.model.hcontig_00...    0.483521     0.467381
# evm.model.pcontig_000.1007_evm.model.hcontig_00...    0.586777     0.514706
# evm.model.pcontig_000.1008_evm.model.hcontig_00...   -0.000000     0.000000
# evm.model.pcontig_000.1009_evm.model.hcontig_00...    0.794521     0.245283
# evm.model.pcontig_000.101_evm.model.hcontig_000...         NaN          NaN
# evm.model.pcontig_000.1010_evm.model.hcontig_00...   -0.000000     0.000000
# evm.model.pcontig_000.1011_evm.model.hcontig_00...   -0.000000     0.000000
# evm.model.pcontig_000.1012_evm.model.hcontig_00...         NaN          NaN
# evm.model.pcontig_000.1014_evm.model.hcontig_00...    0.907127     0.980931
# evm.model.pcontig_000.1015_evm.model.hcontig_00...         NaN          NaN
# evm.model.pcontig_000.1016_evm.model.hcontig_00...         NaN          NaN
# evm.model.pcontig_000.1019_evm.model.hcontig_00...   -0.000000     0.000000
# evm.model.pcontig_000.1020_evm.model.hcontig_00...    0.119898     0.090722
# evm.model.pcontig_000.1021_evm.model.hcontig_00...   -0.000000     0.000000
# evm.model.pcontig_000.1022_evm.model.hcontig_00...    0.131410     0.111111
# evm.model.pcontig_000.1023_evm.model.hcontig_00...    0.082337     0.051163
# evm.model.pcontig_000.1024_evm.model.hcontig_00...    0.364535     0.360772
# evm.model.pcontig_000.1026_evm.model.hcontig_00...    0.563375     0.546499
# evm.model.pcontig_000.1027_evm.model.hcontig_00...         NaN          NaN
# evm.model.pcontig_000.1028_evm.model.hcontig_00...    1.359375     0.805654
# evm.model.pcontig_000.1029_evm.model.hcontig_00...   -0.000000     0.000000
# evm.model.pcontig_000.103_evm.model.hcontig_000...    0.722393     0.606999
# evm.model.pcontig_000.1030_evm.model.hcontig_00...         NaN          NaN
# evm.model.pcontig_000.1031_evm.model.hcontig_00...    1.265659     1.347876
# ...                                                        ...          ...
# evm.model.pcontig_104.1_evm.model.hcontig_021_0...    9.024390     6.751634
# evm.model.pcontig_104.2_evm.model.hcontig_004_0...    0.153846     0.139562
# evm.model.pcontig_104.3_evm.model.hcontig_004_0...    0.021779     0.027738
# evm.model.pcontig_104.4_evm.model.hcontig_026_0...    0.149425     0.124590
# evm.model.pcontig_104.4_evm.model.hcontig_089_0...    0.149425     0.124590
# evm.model.pcontig_105.1_evm.model.hcontig_011_0...    0.187111     0.265203
# evm.model.pcontig_106.1_evm.model.hcontig_018_0...    0.027736     0.073308
# evm.model.pcontig_107.1_evm.model.hcontig_003_0...    0.544974     0.387097
# evm.model.pcontig_107.2_evm.model.hcontig_050_0...         NaN    81.666667
# evm.model.pcontig_107.3_evm.model.hcontig_006_0...    0.056140     0.131932
# evm.model.pcontig_107.4_evm.model.hcontig_009_0...    0.123246     0.107253
# evm.model.pcontig_107.5_evm.model.hcontig_003_0...    0.375276     0.240854
# evm.model.pcontig_107.7_evm.model.hcontig_011_0...    0.198324          NaN
# evm.model.pcontig_109.1_evm.model.hcontig_003_0...    0.744741     0.607544
# evm.model.pcontig_109.2_evm.model.hcontig_003_0...    0.884422     0.823810
# evm.model.pcontig_109.3_evm.model.hcontig_003_0...         NaN          NaN
# evm.model.pcontig_109.4_evm.model.hcontig_003_0...         NaN          NaN
# evm.model.pcontig_109.5_evm.model.hcontig_006_0...    0.739166     0.651076
# evm.model.pcontig_109.6_evm.model.hcontig_006_0...    0.414773     0.323810
# evm.model.pcontig_109.7_evm.model.hcontig_006_0...    0.483871     0.422572
# evm.model.pcontig_109.8_evm.model.hcontig_003_0...    0.521212     0.482659
# evm.model.pcontig_110.1_evm.model.hcontig_065_0...         NaN          NaN
# evm.model.pcontig_110.2_evm.model.hcontig_068_0...         NaN          NaN
# evm.model.pcontig_110.3_evm.model.hcontig_068_0...         NaN          NaN
# evm.model.pcontig_110.4_evm.model.hcontig_068_0...         NaN          NaN
# evm.model.pcontig_110.6_evm.model.hcontig_068_0...         NaN    45.500000
# evm.model.pcontig_110.6_evm.model.hcontig_065_0...         NaN    45.500000
# evm.model.pcontig_110.7_evm.model.hcontig_060_0...    0.018561     0.031632
# evm.model.pcontig_110.8_evm.model.hcontig_057_0...    0.128342     0.083650
# evm.model.pcontig_110.9_evm.model.hcontig_068_0...    1.129412     1.141176
#
#                                                     LWL85m_dN/dS  LPB93_dN/dS
# folder
# evm.model.pcontig_000.1_evm.model.hcontig_000_0...           NaN          NaN
# evm.model.pcontig_000.100_evm.model.hcontig_000...           NaN          NaN
# evm.model.pcontig_000.1000_evm.model.hcontig_00...      0.000000     0.000000
# evm.model.pcontig_000.1001_evm.model.hcontig_00...           NaN          NaN
# evm.model.pcontig_000.1002_evm.model.hcontig_00...           NaN          NaN
# evm.model.pcontig_000.1003_evm.model.hcontig_00...           NaN          NaN
# evm.model.pcontig_000.1005_evm.model.hcontig_00...      0.314064     0.456737
# evm.model.pcontig_000.1007_evm.model.hcontig_00...      0.733333     0.732673
# evm.model.pcontig_000.1008_evm.model.hcontig_00...      0.000000     0.000000
# evm.model.pcontig_000.1009_evm.model.hcontig_00...      0.527473     0.439560
# evm.model.pcontig_000.101_evm.model.hcontig_000...           NaN          NaN
# evm.model.pcontig_000.1010_evm.model.hcontig_00...      0.000000     0.000000
# evm.model.pcontig_000.1011_evm.model.hcontig_00...      0.000000     0.000000
# evm.model.pcontig_000.1012_evm.model.hcontig_00...           NaN          NaN
# evm.model.pcontig_000.1014_evm.model.hcontig_00...      0.779048     0.841661
# evm.model.pcontig_000.1015_evm.model.hcontig_00...           NaN          NaN
# evm.model.pcontig_000.1016_evm.model.hcontig_00...           NaN          NaN
# evm.model.pcontig_000.1019_evm.model.hcontig_00...           NaN     0.000000
# evm.model.pcontig_000.1020_evm.model.hcontig_00...      0.118987     0.123656
# evm.model.pcontig_000.1021_evm.model.hcontig_00...      0.000000     0.000000
# evm.model.pcontig_000.1022_evm.model.hcontig_00...      0.111111     0.139881
# evm.model.pcontig_000.1023_evm.model.hcontig_00...      0.080729     0.075721
# evm.model.pcontig_000.1024_evm.model.hcontig_00...      0.248813     0.351384
# evm.model.pcontig_000.1026_evm.model.hcontig_00...      0.541494     0.558227
# evm.model.pcontig_000.1027_evm.model.hcontig_00...           NaN          NaN
# evm.model.pcontig_000.1028_evm.model.hcontig_00...      0.987603     1.003937
# evm.model.pcontig_000.1029_evm.model.hcontig_00...      0.000000     0.000000
# evm.model.pcontig_000.103_evm.model.hcontig_000...      0.705438     0.688988
# evm.model.pcontig_000.1030_evm.model.hcontig_00...           NaN          NaN
# evm.model.pcontig_000.1031_evm.model.hcontig_00...      0.920502     1.060552
# ...                                                          ...          ...
# evm.model.pcontig_104.1_evm.model.hcontig_021_0...     13.483871    11.967742
# evm.model.pcontig_104.2_evm.model.hcontig_004_0...      0.199391     0.207937
# evm.model.pcontig_104.3_evm.model.hcontig_004_0...      0.040574     0.039200
# evm.model.pcontig_104.4_evm.model.hcontig_026_0...      0.154440     0.108359
# evm.model.pcontig_104.4_evm.model.hcontig_089_0...      0.154440     0.108359
# evm.model.pcontig_105.1_evm.model.hcontig_011_0...      0.292446     0.286849
# evm.model.pcontig_106.1_evm.model.hcontig_018_0...      0.071909     0.080680
# evm.model.pcontig_107.1_evm.model.hcontig_003_0...      0.778523     0.778523
# evm.model.pcontig_107.2_evm.model.hcontig_050_0...           NaN   244.000000
# evm.model.pcontig_107.3_evm.model.hcontig_006_0...      0.129733     0.156702
# evm.model.pcontig_107.4_evm.model.hcontig_009_0...      0.164935     0.158395
# evm.model.pcontig_107.5_evm.model.hcontig_003_0...      0.339286     0.360161
# evm.model.pcontig_107.7_evm.model.hcontig_011_0...           NaN          NaN
# evm.model.pcontig_109.1_evm.model.hcontig_003_0...      0.600159     0.592302
# evm.model.pcontig_109.2_evm.model.hcontig_003_0...      0.583333     0.842105
# evm.model.pcontig_109.3_evm.model.hcontig_003_0...           NaN          NaN
# evm.model.pcontig_109.4_evm.model.hcontig_003_0...           NaN          NaN
# evm.model.pcontig_109.5_evm.model.hcontig_006_0...      0.611033     0.654439
# evm.model.pcontig_109.6_evm.model.hcontig_006_0...      0.241509     0.376289
# evm.model.pcontig_109.7_evm.model.hcontig_006_0...      0.399497     0.436170
# evm.model.pcontig_109.8_evm.model.hcontig_003_0...      0.482659     0.528846
# evm.model.pcontig_110.1_evm.model.hcontig_065_0...           NaN          NaN
# evm.model.pcontig_110.2_evm.model.hcontig_068_0...           NaN          NaN
# evm.model.pcontig_110.3_evm.model.hcontig_068_0...           NaN          NaN
# evm.model.pcontig_110.4_evm.model.hcontig_068_0...           NaN          NaN
# evm.model.pcontig_110.6_evm.model.hcontig_068_0...           NaN    83.000000
# evm.model.pcontig_110.6_evm.model.hcontig_065_0...           NaN    83.000000
# evm.model.pcontig_110.7_evm.model.hcontig_060_0...      0.043604     0.038435
# evm.model.pcontig_110.8_evm.model.hcontig_057_0...      0.173077     0.173077
# evm.model.pcontig_110.9_evm.model.hcontig_068_0...      0.735537     1.400000
#
# [16761 rows x 11 columns]
